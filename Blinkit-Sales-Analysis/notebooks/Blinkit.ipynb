# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('sample_data/Blinkit.csv')

# %%
df.head(10)
# Out:
#    transaction_id                      product_name     product_category  \
# 0               1                 Garlic Naan Bread        Food - Bakery
# 1               2                 Sweet Potato Mash  Food - Frozen Foods
# 2               3             Honey Graham Crackers        Food - Snacks
# 3               4          Car Windshield Sun Shade           Automotive
# 4               5   Kitchen Knife Sharpening System              Kitchen
# 5               6        Outdoor Adventure Backpack              Outdoor
# 6               7  Multi-Function Smartphone Holder          Electronics
# 7               8                  Streaming Device          Electronics
# 8               9                     Electric Bike             Bicycles
# 9              10          Maple Bacon Potato Chips        Food - Snacks
#
#    quantity  unit_price  total_price      customer_name  \
# 0        61       85.10       747.89      Kirk Kenshole
# ...

# %%
df.columns
# Out:
# Index(['transaction_id', 'product_name', 'product_category', 'quantity',
#        'unit_price', 'total_price', 'customer_name', 'customer_email',
#        'purchase_date', 'payment_method', 'City', 'Order_status'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transaction_id    1000 non-null   int64
#  1   product_name      1000 non-null   object
#  2   product_category  1000 non-null   object
#  3   quantity          1000 non-null   int64
#  4   unit_price        1000 non-null   float64
#  5   total_price       1000 non-null   float64
#  6   customer_name     1000 non-null   object
#  7   customer_email    1000 non-null   object
#  8   purchase_date     1000 non-null   object
#  9   payment_method    1000 non-null   object
#  10  City              1000 non-null   object
#  11  Order_status      1000 non-null   object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 93.9+ KB

# %%
df.dtypes
# Out:
# transaction_id        int64
# product_name         object
# product_category     object
# quantity              int64
# unit_price          float64
# total_price         float64
# customer_name        object
# customer_email       object
# purchase_date        object
# payment_method       object
# City                 object
# Order_status         object
# dtype: object

# %%
df.isnull()
# Out:
#      transaction_id  product_name  product_category  quantity  unit_price  \
# 0             False         False             False     False       False
# 1             False         False             False     False       False
# 2             False         False             False     False       False
# 3             False         False             False     False       False
# 4             False         False             False     False       False
# ..              ...           ...               ...       ...         ...
# 995           False         False             False     False       False
# 996           False         False             False     False       False
# 997           False         False             False     False       False
# 998           False         False             False     False       False
# 999           False         False             False     False       False
#
#      total_price  customer_name  customer_email  purchase_date  \
# ...

# %%
df.isnull().sum()
# Out:
# transaction_id      0
# product_name        0
# product_category    0
# quantity            0
# unit_price          0
# total_price         0
# customer_name       0
# customer_email      0
# purchase_date       0
# payment_method      0
# City                0
# Order_status        0
# dtype: int64

# %%
df.isna().sum()
# Out:
# transaction_id      0
# product_name        0
# product_category    0
# quantity            0
# unit_price          0
# total_price         0
# customer_name       0
# customer_email      0
# purchase_date       0
# payment_method      0
# City                0
# Order_status        0
# dtype: int64

# %%
df['transaction_id'].nunique()
# Out:
# 1000

# %%
df['total_price'].sum()
# Out:
# np.float64(516681.30000000005)

# %%
df['total_price'].describe()
# Out:
# count    1000.000000
# mean      516.681300
# std       287.100866
# min         1.070000
# 25%       270.177500
# 50%       528.480000
# 75%       772.807500
# max       999.430000
# Name: total_price, dtype: float64

# %%
df.nlargest(1, 'total_price')
# Out:
#      transaction_id      product_name product_category  quantity  unit_price  \
# 748             749  Black Bean Salsa    Food - Snacks         2       25.35
#
#      total_price     customer_name             customer_email purchase_date  \
# 748       999.43  Corella Waddilow  cwaddilowks@geocities.com      5/9/2022
#
#     payment_method       City Order_status
# 748         PayPal  Ahmedabad      shipped

# %%
df.groupby('product_name')['quantity'].sum().sort_values(ascending=False).head(10)
# Out:
# product_name
# Fruit & Nut Trail Mix         248
# Pineapple Coconut Yogurt      242
# Adjustable Bar Stools         236
# Colorful Post-It Notes Set    228
# Home Karaoke System           223
# Pet Grooming Scissors         198
# Garden Vegetable Chips        197
# Chili Lime Corn Chips         196
# Heavy-Duty Utility Tote       192
# Outdoor Adventure Backpack    191
# Name: quantity, dtype: int64

# %%
df.groupby('product_category')['total_price'].sum().sort_values(ascending=False).head(10)
# Out:
# product_category
# Kitchen              44639.78
# Food - Snacks        35405.55
# Food - Condiments    29478.84
# Home                 27629.19
# Outdoor              23366.43
# Pets                 20201.55
# Fitness              16857.75
# Accessories          13851.26
# Electronics          13431.52
# Food - Bakery        12097.86
# Name: total_price, dtype: float64

# %%
df.groupby('product_name')['quantity'].sum().sort_values(ascending=False)
# Out:
# product_name
# Fruit & Nut Trail Mix         248
# Pineapple Coconut Yogurt      242
# Adjustable Bar Stools         236
# Colorful Post-It Notes Set    228
# Home Karaoke System           223
#                              ...
# Black Bean Salsa                2
# Yoga Mat                        1
# Infrared Thermometer            1
# Ginger Snaps                    1
# Fresh Lemons                    1
# Name: quantity, Length: 770, dtype: int64

# %%
df.groupby('product_category')['total_price'].sum().sort_values(ascending=False).head()
# Out:
# product_category
# Kitchen              44639.78
# Food - Snacks        35405.55
# Food - Condiments    29478.84
# Home                 27629.19
# Outdoor              23366.43
# Name: total_price, dtype: float64

# %%
df.groupby('customer_name')['total_price'].sum().sort_values(ascending=False).head()
# Out:
# customer_name
# Corella Waddilow      999.43
# Jeni Smowton          998.81
# Hobie Sigge           998.32
# Hyacinthie Chasmor    997.60
# Darrel Clemenza       994.85
# Name: total_price, dtype: float64

# %%
(df['customer_name'].value_counts() > 1)
# Out:
# customer_name
# Chas Lashley         False
# Kirk Kenshole        False
# Al Clail             False
# Karita Boskell       False
# Dacie O'Kennavain    False
#                      ...
# Worthy Tournay       False
# Ellwood Tunkin       False
# Paulo Ventris        False
# Ali Skates           False
# Taddeusz Bener       False
# Name: count, Length: 1000, dtype: bool

# %%
df['customer_name'].unique().sum()
# Out:
# "Kirk KensholeAl ClailKarita BoskellDacie O'KennavainVon AichesonCourtney ArmsdenFeliks FischerHaven GarrodTaddeusz BenerAli SkatesPaulo VentrisEllwood TunkinWorthy TournayEmlynne DavidovMoira SlaneAnnabela DrewetCatherina LambolBobbye ParkMarcia LaffinRollins MagnusValentin HuckfieldMaritsa ArnizTallou SanfordCherise MacChaellTonnie CaterObadias CurteisJoleen SplevinCamille HarcombeBrigit FleuryBruce WestleyCarroll LarterMarsh LohdeTerri CapponerChucho WheelbandArlin SherwynTravus PritchittReba ToplisNatala MacKissackGeorges HeatheringtonHenrik McLoughlinBasilius GilesChlo CowenSuzie BrownseyHarlen JoplingMaire CornilVivian TolworthArlin SponDion PostlesAllyson ApsManfred BussenAlysia ShafeJay ExtanceNathan DubockHarrison CristofaniniSarge YandellJuliette De PaepeDdene GreschikJolyn BernaciakBlinnie McMychemAgnella MacDiarmondEmyle RenboldRobena GaishArnold BreezeJerri BalchArielle GainfortGwen HurcombeTamara ThodyHildegarde VardieLarissa DollinKaterine LuttgerAngelica FarnabyIris B
# ...

# %%
df.groupby('customer_name')['total_price'].sum().mean()
# Out:
# np.float64(516.6813)

# %%
df.groupby('City')['total_price'].sum().sort_values(ascending=False).head(5)
# Out:
# City
# Ahmedabad    64393.98
# Lucknow      56182.70
# Hyderabad    55674.69
# Bangalore    54205.72
# Delhi        53116.20
# Name: total_price, dtype: float64

# %%
df['City'].value_counts().head(10)
# Out:
# City
# Ahmedabad    114
# Lucknow      111
# Hyderabad    106
# Chennai      104
# Mumbai       102
# Pune         101
# Bangalore     98
# Delhi         98
# Kolkata       83
# Jaipur        83
# Name: count, dtype: int64

# %%
df.groupby('City')['total_price'].mean()
# Out:
# City
# Ahmedabad    564.859474
# Bangalore    553.119592
# Chennai      453.369135
# Delhi        542.002041
# Hyderabad    525.232925
# Jaipur       495.065060
# Kolkata      519.107831
# Lucknow      506.150450
# Mumbai       485.700196
# Pune         517.226238
# Name: total_price, dtype: float64

# %%
df['payment_method'].value_counts()
# Out:
# payment_method
# Gift card      185
# Google Pay     173
# credit card    172
# Cash           167
# PayPal         160
# Apple Pay      143
# Name: count, dtype: int64

# %%
df.groupby('payment_method')['total_price'].sum()
# Out:
# payment_method
# Apple Pay      75145.71
# Cash           88331.92
# Gift card      93158.42
# Google Pay     86913.74
# PayPal         82316.46
# credit card    90815.05
# Name: total_price, dtype: float64

# %%
df['Order_status'].value_counts()
# Out:
# Order_status
# completed      111
# on hold        108
# pending        106
# cancelled      104
# delivered      102
# refunded       101
# processing      97
# returned        96
# shipped         88
# backordered     87
# Name: count, dtype: int64

# %%
df.groupby('Order_status')['total_price'].sum()
# Out:
# Order_status
# backordered    45247.75
# cancelled      51596.47
# completed      56983.82
# delivered      58891.58
# on hold        52978.44
# pending        55146.67
# processing     51067.68
# refunded       51226.38
# returned       49029.13
# shipped        44513.38
# Name: total_price, dtype: float64

# %%
(df['Order_status'] == 'cancelled').mean()*100
# Out:
# np.float64(10.4)

# %%
df.groupby('purchase_date')['total_price'].sum().sort_values(ascending=False).head(10)
# Out:
# purchase_date
# 6/21/2021     2517.34
# 7/29/2025     2270.98
# 12/16/2026    2171.76
# 3/9/2020      2096.84
# 1/14/2021     2013.47
# 5/9/2022      1928.74
# 5/5/2020      1839.03
# 10/30/2025    1770.73
# 3/18/2026     1756.94
# 6/15/2021     1752.01
# Name: total_price, dtype: float64

# %%
df.groupby('purchase_date')['total_price'].sum().idxmax()
# Out:
# '6/21/2021'

# %%
df['purchase_date'] = pd.to_datetime(df['purchase_date'])
df.groupby(df['purchase_date'].dt.month)['total_price'].sum()
# Out:
# purchase_date
# 1     46415.39
# 2     37854.62
# 3     46580.52
# 4     48496.94
# 5     41001.71
# 6     40297.68
# 7     57426.07
# 8     46484.80
# 9     39787.10
# 10    38676.60
# 11    32113.67
# 12    41546.20
# Name: total_price, dtype: float64
